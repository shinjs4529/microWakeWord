# %% [markdown]
# # Training a microWakeWord Model
#
# This notebook steps you through training a basic microWakeWord model. It is intended as a **starting point** for advanced users. You should use Python 3.10.
#
# **The model generated will most likely not be usable for everyday use; it may be difficult to trigger or falsely activates too frequently. You will most likely have to experiment with many different settings to obtain a decent model!**
#
# In the comment at the start of certain blocks, I note some specific settings to consider modifying.
#
# This runs on Google Colab, but is extremely slow compared to training on a local GPU. If you must use Colab, be sure to Change the runtime type to a GPU. Even then, it still slow!
#
# At the end of this notebook, you will be able to download a tflite file. To use this in ESPHome, you need to write a model manifest JSON file. See the [ESPHome documentation](https://esphome.io/components/micro_wake_word) for the details and the [model repo](https://github.com/esphome/micro-wake-word-models/tree/main/models/v2) for examples.

# %%
# Installs microWakeWord. Be sure to restart the session after this is finished.
import platform
import os

if platform.system() == "Darwin":
    # `pymicro-features` is installed from a fork to support building on macOS
    # !pip install 'git+https://github.com/puddly/pymicro-features@puddly/minimum-cpp-version'

# `audio-metadata` is installed from a fork to unpin `attrs` from a version that breaks Jupyter
# !pip install 'git+https://github.com/whatsnowplaying/audio-metadata@d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f'

if not os.path.exists("./microWakeWord"):
    # !git clone https://github.com/kahrendt/microWakeWord
    # !sed -i 's/stride_ms=step_ms/step_ms=step_ms/' microWakeWord/microwakeword/inference.py
    # !pip install -e ./microWakeWord
# Out:
# Collecting git+https://github.com/whatsnowplaying/audio-metadata@d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f
#   Cloning https://github.com/whatsnowplaying/audio-metadata (to revision d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f) to /tmp/pip-req-build-sf9ovfod
#   Running command git clone --filter=blob:none --quiet https://github.com/whatsnowplaying/audio-metadata /tmp/pip-req-build-sf9ovfod
#   Running command git rev-parse -q --verify 'sha^d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f'
#   Running command git fetch -q https://github.com/whatsnowplaying/audio-metadata d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f
#   Running command git checkout -q d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f
#   Resolved https://github.com/whatsnowplaying/audio-metadata to commit d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: attrs>=18.2 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from audio-metadata==0.12.0) (25.3.0)
# Requirement already satisfied: bidict==0.* in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from audio-metadata==0.12.0) (0.23.1)
# Requirement already satisfied: bitstruct<9.0,>=6.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from audio-metadata==0.12.0) (8.21.0)
# Requirement already satisfied: more-itertools<9.0,>=4.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from audio-metadata==0.12.0) (8.14.0)
# Requirement already satisfied: pprintpp==0.* in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from audio-metadata==0.12.0) (0.4.0)
# Requirement already satisfied: wrapt<2.0,>=1.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from audio-metadata==0.12.0) (1.17.2)
# fatal: destination path 'microWakeWord' already exists and is not an empty directory.
# Obtaining file:///home/kist/Workspace/Python/microWakeWord/notebooks/microWakeWord
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: audiomentations in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from microwakeword==0.1.0) (0.42.0)
# Requirement already satisfied: audio_metadata in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from microwakeword==0.1.0) (0.12.0)
# Requirement already satisfied: datasets in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from microwakeword==0.1.0) (3.6.0)
# Requirement already satisfied: mmap_ninja in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from microwakeword==0.1.0) (0.7.4)
# Requirement already satisfied: numpy in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from microwakeword==0.1.0) (1.26.4)
# Requirement already satisfied: pymicro-features in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from microwakeword==0.1.0) (1.0.0)
# Requirement already satisfied: pyyaml in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from microwakeword==0.1.0) (6.0.2)
# Requirement already satisfied: tensorflow>=2.16 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from microwakeword==0.1.0) (2.16.2)
# Requirement already satisfied: webrtcvad in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from microwakeword==0.1.0) (2.0.10)
# Requirement already satisfied: absl-py>=1.0.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (3.14.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (3.4.0)
# Requirement already satisfied: packaging in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (2.32.4)
# Requirement already satisfied: setuptools in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (1.73.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (3.10.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (0.37.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.16->microwakeword==0.1.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.16->microwakeword==0.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.16->microwakeword==0.1.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.16->microwakeword==0.1.0) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.16->microwakeword==0.1.0) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.16->microwakeword==0.1.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.16->microwakeword==0.1.0) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow>=2.16->microwakeword==0.1.0) (0.45.1)
# Requirement already satisfied: rich in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow>=2.16->microwakeword==0.1.0) (14.0.0)
# Requirement already satisfied: namex in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow>=2.16->microwakeword==0.1.0) (0.1.0)
# Requirement already satisfied: optree in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow>=2.16->microwakeword==0.1.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow>=2.16->microwakeword==0.1.0) (3.0.2)
# Requirement already satisfied: attrs>=18.2 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from audio_metadata->microwakeword==0.1.0) (25.3.0)
# Requirement already satisfied: bidict==0.* in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from audio_metadata->microwakeword==0.1.0) (0.23.1)
# Requirement already satisfied: bitstruct<9.0,>=6.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from audio_metadata->microwakeword==0.1.0) (8.21.0)
# Requirement already satisfied: more-itertools<9.0,>=4.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from audio_metadata->microwakeword==0.1.0) (8.14.0)
# Requirement already satisfied: pprintpp==0.* in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from audio_metadata->microwakeword==0.1.0) (0.4.0)
# Requirement already satisfied: numpy-minmax<1,>=0.3.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from audiomentations->microwakeword==0.1.0) (0.3.1)
# Requirement already satisfied: numpy-rms<1,>=0.4.2 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from audiomentations->microwakeword==0.1.0) (0.4.2)
# Requirement already satisfied: librosa!=0.10.0,<0.12.0,>=0.8.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from audiomentations->microwakeword==0.1.0) (0.11.0)
# Requirement already satisfied: python-stretch<1,>=0.3.1 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from audiomentations->microwakeword==0.1.0) (0.3.1)
# Requirement already satisfied: scipy<2,>=1.4 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from audiomentations->microwakeword==0.1.0) (1.15.3)
# Requirement already satisfied: soxr<1.0.0,>=0.3.2 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from audiomentations->microwakeword==0.1.0) (0.5.0.post1)
# Requirement already satisfied: audioread>=2.1.9 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (0.61.2)
# Requirement already satisfied: scikit-learn>=1.1.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (1.7.0)
# Requirement already satisfied: joblib>=1.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (5.2.1)
# Requirement already satisfied: soundfile>=0.12.1 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (1.8.2)
# Requirement already satisfied: lazy_loader>=0.1 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (1.1.1)
# Requirement already satisfied: cffi>=1.0.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from numpy-minmax<1,>=0.3.0->audiomentations->microwakeword==0.1.0) (1.17.1)
# Requirement already satisfied: pycparser in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from cffi>=1.0.0->numpy-minmax<1,>=0.3.0->audiomentations->microwakeword==0.1.0) (2.22)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from numba>=0.51.0->librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from pooch>=1.1->librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (4.3.8)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from scikit-learn>=1.1.0->librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (3.6.0)
# Requirement already satisfied: filelock in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from datasets->microwakeword==0.1.0) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from datasets->microwakeword==0.1.0) (20.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from datasets->microwakeword==0.1.0) (0.3.8)
# Requirement already satisfied: pandas in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from datasets->microwakeword==0.1.0) (2.3.0)
# Requirement already satisfied: tqdm>=4.66.3 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from datasets->microwakeword==0.1.0) (4.67.1)
# Requirement already satisfied: xxhash in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from datasets->microwakeword==0.1.0) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from datasets->microwakeword==0.1.0) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from datasets->microwakeword==0.1.0) (0.33.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0) (3.12.13)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0) (1.20.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from huggingface-hub>=0.24.0->datasets->microwakeword==0.1.0) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from pandas->datasets->microwakeword==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from pandas->datasets->microwakeword==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from pandas->datasets->microwakeword==0.1.0) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow>=2.16->microwakeword==0.1.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow>=2.16->microwakeword==0.1.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/kist/Workspace/Python/microWakeWord/.venv3.10/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow>=2.16->microwakeword==0.1.0) (0.1.2)
# Building wheels for collected packages: microwakeword
#   Building editable for microwakeword (pyproject.toml) ... done
#   Created wheel for microwakeword: filename=microwakeword-0.1.0-0.editable-py3-none-any.whl size=9922 sha256=d11c251bf9bbf41d4a01af51bde1de6db090a6c6c1a38758e0f3cde06e00acee
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ftesm473/wheels/f2/df/41/1ca112623cf3c31535d5768d6bb942ad1a85aa870a6dba0f4e
# Successfully built microwakeword
# Installing collected packages: microwakeword
#   Attempting uninstall: microwakeword
#     Found existing installation: microwakeword 0.1.0
#     Uninstalling microwakeword-0.1.0:
#       Successfully uninstalled microwakeword-0.1.0
# Successfully installed microwakeword-0.1.0

# %%
# Generates 1 sample of the target word for manual verification.

target_word = 'ddolddolah'  # Phonetic spellings may produce better samples

import os
import sys
import platform

from IPython.display import Audio

if not os.path.exists("./piper-sample-generator"):
    if platform.system() == "Darwin":
        # !git clone -b mps-support https://github.com/kahrendt/piper-sample-generator
    else:
        # !git clone https://github.com/rhasspy/piper-sample-generator

    # !wget -O piper-sample-generator/models/en_US-libritts_r-medium.pt 'https://github.com/rhasspy/piper-sample-generator/releases/download/v2.0.0/en_US-libritts_r-medium.pt'

    # Install system dependencies
    # !pip install torch torchaudio piper-phonemize-cross==1.2.1

    if "piper-sample-generator/" not in sys.path:
        sys.path.append("piper-sample-generator/")

# !python3 piper-sample-generator/generate_samples.py "{target_word}" \
--max-samples 1 \
--batch-size 1 \
--output-dir generated_samples

Audio("generated_samples/0.wav", autoplay=True)
# Out:
# DEBUG:__main__:Loading /home/kist/Workspace/Python/microWakeWord/notebooks/piper-sample-generator/models/en_US-libritts_r-medium.pt
# /home/kist/Workspace/Python/microWakeWord/notebooks/piper-sample-generator/generate_samples.py:76: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch_model = torch.load(model_path)
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:CUDA available, using GPU
# DEBUG:__main__:Batch 1/1 complete
# INFO:__main__:Done
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Generates a larger amount of wake word samples.
# Start here when trying to improve your model.
# See https://github.com/rhasspy/piper-sample-generator for the full set of
# parameters. In particular, experiment with noise-scales and noise-scale-ws,
# generating negative samples similar to the wake word, and generating many more
# wake word samples, possibly with different phonetic pronunciations.

# !python3 piper-sample-generator/generate_samples.py "{target_word}" \
--max-samples 1000 \
--batch-size 100 \
--output-dir generated_samples
# Out:
# DEBUG:__main__:Loading /home/kist/Workspace/Python/microWakeWord/notebooks/piper-sample-generator/models/en_US-libritts_r-medium.pt
# /home/kist/Workspace/Python/microWakeWord/notebooks/piper-sample-generator/generate_samples.py:76: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch_model = torch.load(model_path)
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:CUDA available, using GPU
# DEBUG:__main__:Batch 1/10 complete
# DEBUG:__main__:Batch 2/10 complete
# DEBUG:__main__:Batch 3/10 complete
# DEBUG:__main__:Batch 4/10 complete
# DEBUG:__main__:Batch 5/10 complete
# DEBUG:__main__:Batch 6/10 complete
# DEBUG:__main__:Batch 7/10 complete
# DEBUG:__main__:Batch 8/10 complete
# DEBUG:__main__:Batch 9/10 complete
# DEBUG:__main__:Batch 10/10 complete
# INFO:__main__:Done

# %%
# Downloads audio data for augmentation. This can be slow!
# Borrowed from openWakeWord's automatic_model_training.ipynb, accessed March 4, 2024
#
# **Important note!** The data downloaded here has a mixture of difference
# licenses and usage restrictions. As such, any custom models trained with this
# data should be considered as appropriate for **non-commercial** personal use only.


import datasets
import scipy
import os

import numpy as np

from pathlib import Path
from tqdm import tqdm

## Download MIR RIR data

output_dir = "./mit_rirs"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
    rir_dataset = datasets.load_dataset("davidscripka/MIT_environmental_impulse_responses", split="train", streaming=True)
    # Save clips to 16-bit PCM wav files
    for row in tqdm(rir_dataset):
        name = row['audio']['path'].split('/')[-1]
        scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))

## Download noise and background audio

# Audioset Dataset (https://research.google.com/audioset/dataset/index.html)
# Download one part of the audioset .tar files, extract, and convert to 16khz
# For full-scale training, it's recommended to download the entire dataset from
# https://huggingface.co/datasets/agkphysics/AudioSet, and
# even potentially combine it with other background noise datasets (e.g., FSD50k, Freesound, etc.)

if not os.path.exists("audioset"):
    os.mkdir("audioset")

    fname = "bal_train09.tar"
    out_dir = f"audioset/{fname}"
    link = "https://huggingface.co/datasets/agkphysics/AudioSet/resolve/main/data/" + fname
    # !wget -O {out_dir} {link}
    # !cd audioset && tar -xf bal_train09.tar

    output_dir = "./audioset_16k"
    if not os.path.exists(output_dir):
        os.mkdir(output_dir)

    # Save clips to 16-bit PCM wav files
    audioset_dataset = datasets.Dataset.from_dict({"audio": [str(i) for i in Path("audioset/audio").glob("**/*.flac")]})
    audioset_dataset = audioset_dataset.cast_column("audio", datasets.Audio(sampling_rate=16000))
    for row in tqdm(audioset_dataset):
        name = row['audio']['path'].split('/')[-1].replace(".flac", ".wav")
        scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))

# Free Music Archive dataset
# https://github.com/mdeff/fma
# (Third-party mchl914 extra small set)

output_dir = "./fma"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
    fname = "fma_xs.zip"
    link = "https://huggingface.co/datasets/mchl914/fma_xsmall/resolve/main/" + fname
    out_dir = f"fma/{fname}"
    # !wget -O {out_dir} {link}
    # !cd {output_dir} && unzip -q {fname}

    output_dir = "./fma_16k"
    if not os.path.exists(output_dir):
        os.mkdir(output_dir)

    # Save clips to 16-bit PCM wav files
    fma_dataset = datasets.Dataset.from_dict({"audio": [str(i) for i in Path("fma/fma_small").glob("**/*.mp3")]})
    fma_dataset = fma_dataset.cast_column("audio", datasets.Audio(sampling_rate=16000))
    for row in tqdm(fma_dataset):
        name = row['audio']['path'].split('/')[-1].replace(".mp3", ".wav")
        scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))

# %%
# Sets up the augmentations.
# To improve your model, experiment with these settings and use more sources of
# background clips.

from microwakeword.audio.augmentation import Augmentation
from microwakeword.audio.clips import Clips
from microwakeword.audio.spectrograms import SpectrogramGeneration

clips = Clips(input_directory='generated_samples',
              file_pattern='*.wav',
              max_clip_duration_s=None,
              remove_silence=False,
              random_split_seed=10,
              split_count=0.1,
              )
augmenter = Augmentation(augmentation_duration_s=3.2,
                         augmentation_probabilities = {
                                "SevenBandParametricEQ": 0.1,
                                "TanhDistortion": 0.1,
                                "PitchShift": 0.1,
                                "BandStopFilter": 0.1,
                                "AddColorNoise": 0.1,
                                "AddBackgroundNoise": 0.75,
                                "Gain": 1.0,
                                "RIR": 0.5,
                            },
                         impulse_paths = ['mit_rirs'],
                         background_paths = ['fma_16k', 'audioset_16k'],
                         background_min_snr_db = -5,
                         background_max_snr_db = 10,
                         min_jitter_s = 0.195,
                         max_jitter_s = 0.205,
                         )

# %%
# Augment a random clip and play it back to verify it works well

from IPython.display import Audio
from microwakeword.audio.audio_utils import save_clip

random_clip = clips.get_random_clip()
augmented_clip = augmenter.augment_clip(random_clip)
save_clip(augmented_clip, 'augmented_clip.wav')

Audio("augmented_clip.wav", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Augment samples and save the training, validation, and testing sets.
# Validating and testing samples generated the same way can make the model
# benchmark better than it performs in real-word use. Use real samples or TTS
# samples generated with a different TTS engine to potentially get more accurate
# benchmarks.

import os
from mmap_ninja.ragged import RaggedMmap

output_dir = 'generated_augmented_features'

if not os.path.exists(output_dir):
    os.mkdir(output_dir)

splits = ["training", "validation", "testing"]
for split in splits:
  out_dir = os.path.join(output_dir, split)
  if not os.path.exists(out_dir):
      os.mkdir(out_dir)


  split_name = "train"
  repetition = 2

  spectrograms = SpectrogramGeneration(clips=clips,
                                     augmenter=augmenter,
                                     slide_frames=10,    # Uses the same spectrogram repeatedly, just shifted over by one frame. This simulates the streaming inferences while training/validating in nonstreaming mode.
                                     step_ms=10,
                                     )
  if split == "validation":
    split_name = "validation"
    repetition = 1
  elif split == "testing":
    split_name = "test"
    repetition = 1
    spectrograms = SpectrogramGeneration(clips=clips,
                                     augmenter=augmenter,
                                     slide_frames=1,    # The testing set uses the streaming version of the model, so no artificial repetition is necessary
                                     step_ms=10,
                                     )

  RaggedMmap.from_generator(
      out_dir=os.path.join(out_dir, 'wakeword_mmap'),
      sample_generator=spectrograms.spectrogram_generator(split=split_name, repeat=repetition),
      batch_size=100,
      verbose=True,
  )
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
# Downloads pre-generated spectrogram features (made for microWakeWord in
# particular) for various negative datasets. This can be slow!

output_dir = './negative_datasets'
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
    link_root = "https://huggingface.co/datasets/kahrendt/microwakeword/resolve/main/"
    filenames = ['dinner_party.zip', 'dinner_party_eval.zip', 'no_speech.zip', 'speech.zip']
    for fname in filenames:
        link = link_root + fname

        zip_path = f"negative_datasets/{fname}"
        # !wget -O {zip_path} {link}
        # !unzip -q {zip_path} -d {output_dir}

# %%
# Save a yaml config that controls the training process
# These hyperparamters can make a huge different in model quality.
# Experiment with sampling and penalty weights and increasing the number of
# training steps.

import yaml
import os

config = {}

config["window_step_ms"] = 10

config["train_dir"] = (
    "trained_models/wakeword"
)


# Each feature_dir should have at least one of the following folders with this structure:
#  training/
#    ragged_mmap_folders_ending_in_mmap
#  testing/
#    ragged_mmap_folders_ending_in_mmap
#  testing_ambient/
#    ragged_mmap_folders_ending_in_mmap
#  validation/
#    ragged_mmap_folders_ending_in_mmap
#  validation_ambient/
#    ragged_mmap_folders_ending_in_mmap
#
#  sampling_weight: Weight for choosing a spectrogram from this set in the batch
#  penalty_weight: Penalizing weight for incorrect predictions from this set
#  truth: Boolean whether this set has positive samples or negative samples
#  truncation_strategy = If spectrograms in the set are longer than necessary for training, how are they truncated
#       - random: choose a random portion of the entire spectrogram - useful for long negative samples
#       - truncate_start: remove the start of the spectrogram
#       - truncate_end: remove the end of the spectrogram
#       - split: Split the longer spectrogram into separate spectrograms offset by 100 ms. Only for ambient sets

config["features"] = [
    {
        "features_dir": "generated_augmented_features",
        "sampling_weight": 2.0,
        "penalty_weight": 1.0,
        "truth": True,
        "truncation_strategy": "truncate_start",
        "type": "mmap",
    },
    {
        "features_dir": "negative_datasets/speech",
        "sampling_weight": 10.0,
        "penalty_weight": 1.0,
        "truth": False,
        "truncation_strategy": "random",
        "type": "mmap",
    },
    {
        "features_dir": "negative_datasets/dinner_party",
        "sampling_weight": 10.0,
        "penalty_weight": 1.0,
        "truth": False,
        "truncation_strategy": "random",
        "type": "mmap",
    },
    {
        "features_dir": "negative_datasets/no_speech",
        "sampling_weight": 5.0,
        "penalty_weight": 1.0,
        "truth": False,
        "truncation_strategy": "random",
        "type": "mmap",
    },
    { # Only used for validation and testing
        "features_dir": "negative_datasets/dinner_party_eval",
        "sampling_weight": 0.0,
        "penalty_weight": 1.0,
        "truth": False,
        "truncation_strategy": "split",
        "type": "mmap",
    },
]

# Number of training steps in each iteration - various other settings are configured as lists that corresponds to different steps
config["training_steps"] = [10000]

# Penalizing weight for incorrect class predictions - lists that correspond to training steps
config["positive_class_weight"] = [1]
config["negative_class_weight"] = [20]

config["learning_rates"] = [
    0.001,
]  # Learning rates for Adam optimizer - list that corresponds to training steps
config["batch_size"] = 128

config["time_mask_max_size"] = [
    0
]  # SpecAugment - list that corresponds to training steps
config["time_mask_count"] = [0]  # SpecAugment - list that corresponds to training steps
config["freq_mask_max_size"] = [
    0
]  # SpecAugment - list that corresponds to training steps
config["freq_mask_count"] = [0]  # SpecAugment - list that corresponds to training steps

config["eval_step_interval"] = (
    500  # Test the validation sets after every this many steps
)
config["clip_duration_ms"] = (
    1500  # Maximum length of wake word that the streaming model will accept
)

# The best model weights are chosen first by minimizing the specified minimization metric below the specified target_minimization
# Once the target has been met, it chooses the maximum of the maximization metric. Set 'minimization_metric' to None to only maximize
# Available metrics:
#   - "loss" - cross entropy error on validation set
#   - "accuracy" - accuracy of validation set
#   - "recall" - recall of validation set
#   - "precision" - precision of validation set
#   - "false_positive_rate" - false positive rate of validation set
#   - "false_negative_rate" - false negative rate of validation set
#   - "ambient_false_positives" - count of false positives from the split validation_ambient set
#   - "ambient_false_positives_per_hour" - estimated number of false positives per hour on the split validation_ambient set
config["target_minimization"] = 0.9
config["minimization_metric"] = None  # Set to None to disable

config["maximization_metric"] = "average_viable_recall"

with open(os.path.join("training_parameters.yaml"), "w") as file:
    documents = yaml.dump(config, file)

# %%
# Trains a model. When finished, it will quantize and convert the model to a
# streaming version suitable for on-device detection.
# It will resume if stopped, but it will start over at the configured training
# steps in the yaml file.
# Change --train 0 to only convert and test the best-weighted model.
# On Google colab, it doesn't print the mini-batch results, so it may appear
# stuck for several minutes! Additionally, it is very slow compared to training
# on a local GPU.

# !python -m microwakeword.model_train_eval \
--training_config='training_parameters.yaml' \
--train 1 \
--restore_checkpoint 1 \
--test_tf_nonstreaming 0 \
--test_tflite_nonstreaming 0 \
--test_tflite_nonstreaming_quantized 0 \
--test_tflite_streaming 1 \
--test_tflite_streaming_quantized 0 \
--use_weights "best_weights" \
mixednet \
--pointwise_filters "64,64,64,64" \
--repeat_in_block  "1, 1, 1, 1" \
--mixconv_kernel_sizes '[5], [7,11], [9,15], [23]' \
--residual_connection "0,0,0,0" \
--first_conv_filters 32 \
--first_conv_kernel_size 5 \
--stride 3
# Out:
# 2025-07-17 14:43:09.587142: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-17 14:43:09.601647: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-17 14:43:09.601676: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-17 14:43:09.611131: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-17 14:43:10.152344: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO:absl:Loading and analyzing data sets.
# 2025-07-17 14:43:17.751626: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-07-17 14:43:17.788357: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 4
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 10
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 14
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 22
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 16
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (128, 204, 40)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expand_dims         │ (128, 204, 1, 40) │          0 │ input_layer[0][0] │
# │ (ExpandDims)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream (Stream)     │ (128, 67, 1, 32)  │      6,400 │ expand_dims[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (128, 67, 1, 32)  │          0 │ stream[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_1 (Stream)   │ (128, 67, 1, 32)  │          0 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d    │ (128, 63, 1, 32)  │        192 │ stream_1[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (128, 63, 1, 64)  │      2,048 │ depthwise_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (128, 63, 1, 64)  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (128, 63, 1, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_2 (Stream)   │ (128, 63, 1, 64)  │          0 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ channel_split       │ [(128, 63, 1,     │          0 │ stream_2[0][0]    │
# │ (ChannelSplit)      │ 32), (128, 63, 1, │            │                   │
# │                     │ 32)]              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep        │ (128, 63, 1, 32)  │          0 │ channel_split[0]… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_1      │ (128, 63, 1, 32)  │          0 │ channel_split[0]… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_1  │ (128, 57, 1, 32)  │        256 │ strided_keep[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_2  │ (128, 53, 1, 32)  │        384 │ strided_keep_1[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop        │ (128, 53, 1, 32)  │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_1      │ (128, 53, 1, 32)  │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (128, 53, 1, 64)  │          0 │ strided_drop[0][… │
# │ (Concatenate)       │                   │            │ strided_drop_1[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (128, 53, 1, 64)  │      4,096 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (128, 53, 1, 64)  │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (128, 53, 1, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_3 (Stream)   │ (128, 53, 1, 64)  │          0 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ channel_split_1     │ [(128, 53, 1,     │          0 │ stream_3[0][0]    │
# │ (ChannelSplit)      │ 32), (128, 53, 1, │            │                   │
# │                     │ 32)]              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_2      │ (128, 53, 1, 32)  │          0 │ channel_split_1[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_3      │ (128, 53, 1, 32)  │          0 │ channel_split_1[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_3  │ (128, 45, 1, 32)  │        320 │ strided_keep_2[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4  │ (128, 39, 1, 32)  │        512 │ strided_keep_3[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_2      │ (128, 39, 1, 32)  │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_3      │ (128, 39, 1, 32)  │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (128, 39, 1, 64)  │          0 │ strided_drop_2[0… │
# │ (Concatenate)       │                   │            │ strided_drop_3[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (128, 39, 1, 64)  │      4,096 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (128, 39, 1, 64)  │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (128, 39, 1, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_4 (Stream)   │ (128, 39, 1, 64)  │          0 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_5  │ (128, 17, 1, 64)  │      1,536 │ stream_4[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (128, 17, 1, 64)  │      4,096 │ depthwise_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (128, 17, 1, 64)  │        256 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (128, 17, 1, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_5 (Stream)   │ (128, 17, 1, 64)  │          0 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (128, 1088)       │          0 │ stream_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (128, 1)          │      1,089 │ flatten[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 26,049 (101.75 KB)
#  Trainable params: 25,537 (99.75 KB)
#  Non-trainable params: 512 (2.00 KB)
# INFO:absl:None
# INFO:absl:Step #500: rate 0.001000, accuracy 99.63%, recall 97.40%, precision 97.52%, cross entropy 0.012919
# 2025-07-17 14:43:32.547429: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 3786958080 exceeds 10% of free system memory.
# INFO:absl:Step 500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 94.60%, recall = 94.60%, precision = 100.00%, ambient false positives = 139, estimated false positives per hour = 14.37365, loss = 0.00479, auc = 0.99524, average viable recall = 0.800135467
# INFO:absl:Sharding callback duration: 28
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 80.01355%; no faph cutoff is 1.00
# INFO:absl:Step #1000: rate 0.001000, accuracy 99.87%, recall 99.18%, precision 99.01%, cross entropy 0.003824
# 2025-07-17 14:43:49.973679: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 3786958080 exceeds 10% of free system memory.
# INFO:absl:Step 1000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 94.00%, recall = 94.00%, precision = 100.00%, ambient false positives = 97, estimated false positives per hour = 10.03053, loss = 0.00392, auc = 0.99332, average viable recall = 0.765800212
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 80.01355%; no faph cutoff is 1.00
# INFO:absl:Step #1500: rate 0.001000, accuracy 99.93%, recall 99.66%, precision 99.45%, cross entropy 0.002020
# 2025-07-17 14:44:07.523557: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 3786958080 exceeds 10% of free system memory.
# INFO:absl:Step 1500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 95.60%, recall = 95.60%, precision = 100.00%, ambient false positives = 128, estimated false positives per hour = 13.23617, loss = 0.00454, auc = 0.99433, average viable recall = 0.708328589
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 80.01355%; no faph cutoff is 1.00
# INFO:absl:Step #2000: rate 0.001000, accuracy 99.96%, recall 99.82%, precision 99.67%, cross entropy 0.001461
# 2025-07-17 14:44:25.285441: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 3786958080 exceeds 10% of free system memory.
# INFO:absl:Step 2000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 91.50%, recall = 91.50%, precision = 100.00%, ambient false positives = 47, estimated false positives per hour = 4.86015, loss = 0.00409, auc = 0.98887, average viable recall = 0.769865801
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 80.01355%; no faph cutoff is 1.00
# INFO:absl:Step #2500: rate 0.001000, accuracy 99.96%, recall 99.81%, precision 99.60%, cross entropy 0.001358
# 2025-07-17 14:44:42.364868: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 3786958080 exceeds 10% of free system memory.
# INFO:absl:Step 2500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 91.90%, recall = 91.90%, precision = 100.00%, ambient false positives = 40, estimated false positives per hour = 4.13630, loss = 0.00359, auc = 0.99290, average viable recall = 0.797861035
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 80.01355%; no faph cutoff is 1.00
# INFO:absl:Step #3000: rate 0.001000, accuracy 99.97%, recall 99.83%, precision 99.70%, cross entropy 0.001086
# INFO:absl:Step 3000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 92.60%, recall = 92.60%, precision = 100.00%, ambient false positives = 49, estimated false positives per hour = 5.06697, loss = 0.00377, auc = 0.99037, average viable recall = 0.760265890
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 80.01355%; no faph cutoff is 1.00
# INFO:absl:Step #3500: rate 0.001000, accuracy 99.96%, recall 99.83%, precision 99.62%, cross entropy 0.001089
# INFO:absl:Step 3500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 93.20%, recall = 93.20%, precision = 100.00%, ambient false positives = 47, estimated false positives per hour = 4.86015, loss = 0.00357, auc = 0.99240, average viable recall = 0.785388385
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 80.01355%; no faph cutoff is 1.00
# INFO:absl:Step #4000: rate 0.001000, accuracy 99.96%, recall 99.90%, precision 99.63%, cross entropy 0.001065
# INFO:absl:Step 4000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 92.80%, recall = 92.80%, precision = 100.00%, ambient false positives = 35, estimated false positives per hour = 3.61926, loss = 0.00327, auc = 0.99193, average viable recall = 0.882803572
# INFO:absl:Sharding callback duration: 31
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 88.28036%; no faph cutoff is 1.00
# INFO:absl:Step #4500: rate 0.001000, accuracy 99.97%, recall 99.87%, precision 99.75%, cross entropy 0.000912
# INFO:absl:Step 4500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 91.20%, recall = 91.20%, precision = 100.00%, ambient false positives = 16, estimated false positives per hour = 1.65452, loss = 0.00422, auc = 0.98194, average viable recall = 0.846024557
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 88.28036%; no faph cutoff is 1.00
# INFO:absl:Step #5000: rate 0.001000, accuracy 99.98%, recall 99.92%, precision 99.81%, cross entropy 0.000855
# INFO:absl:Step 5000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 90.60%, recall = 90.60%, precision = 100.00%, ambient false positives = 14, estimated false positives per hour = 1.44771, loss = 0.00446, auc = 0.97945, average viable recall = 0.854223724
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 88.28036%; no faph cutoff is 1.00
# INFO:absl:Step #5500: rate 0.001000, accuracy 99.98%, recall 99.89%, precision 99.79%, cross entropy 0.000964
# INFO:absl:Step 5500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 92.80%, recall = 92.80%, precision = 100.00%, ambient false positives = 33, estimated false positives per hour = 3.41245, loss = 0.00350, auc = 0.98992, average viable recall = 0.861608822
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 88.28036%; no faph cutoff is 1.00
# INFO:absl:Step #6000: rate 0.001000, accuracy 99.98%, recall 99.90%, precision 99.85%, cross entropy 0.000465
# INFO:absl:Step 6000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 92.80%, recall = 92.80%, precision = 100.00%, ambient false positives = 26, estimated false positives per hour = 2.68860, loss = 0.00298, auc = 0.99294, average viable recall = 0.890022397
# INFO:absl:Sharding callback duration: 30
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 89.00224%; no faph cutoff is 1.00
# INFO:absl:Step #6500: rate 0.001000, accuracy 99.97%, recall 99.90%, precision 99.75%, cross entropy 0.000686
# INFO:absl:Step 6500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 92.00%, recall = 92.00%, precision = 100.00%, ambient false positives = 19, estimated false positives per hour = 1.96474, loss = 0.00408, auc = 0.98644, average viable recall = 0.827623008
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 89.00224%; no faph cutoff is 1.00
# INFO:absl:Step #7000: rate 0.001000, accuracy 99.98%, recall 99.92%, precision 99.85%, cross entropy 0.000416
# INFO:absl:Step 7000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 90.20%, recall = 90.20%, precision = 100.00%, ambient false positives = 13, estimated false positives per hour = 1.34430, loss = 0.00530, auc = 0.97995, average viable recall = 0.841533131
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 89.00224%; no faph cutoff is 1.00
# INFO:absl:Step #7500: rate 0.001000, accuracy 99.99%, recall 99.96%, precision 99.89%, cross entropy 0.000324
# INFO:absl:Step 7500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 91.60%, recall = 91.60%, precision = 100.00%, ambient false positives = 15, estimated false positives per hour = 1.55111, loss = 0.00477, auc = 0.97946, average viable recall = 0.858932635
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 89.00224%; no faph cutoff is 1.00
# INFO:absl:Step #8000: rate 0.001000, accuracy 99.97%, recall 99.83%, precision 99.74%, cross entropy 0.000957
# INFO:absl:Step 8000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 90.90%, recall = 90.90%, precision = 100.00%, ambient false positives = 11, estimated false positives per hour = 1.13748, loss = 0.00551, auc = 0.97446, average viable recall = 0.880764532
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 89.00224%; no faph cutoff is 1.00
# INFO:absl:Step #8500: rate 0.001000, accuracy 99.98%, recall 99.92%, precision 99.81%, cross entropy 0.000758
# INFO:absl:Step 8500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 89.20%, recall = 89.20%, precision = 100.00%, ambient false positives = 6, estimated false positives per hour = 0.62045, loss = 0.00682, auc = 0.96748, average viable recall = 0.873985080
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 89.00224%; no faph cutoff is 1.00
# INFO:absl:Step #9000: rate 0.001000, accuracy 99.98%, recall 99.92%, precision 99.83%, cross entropy 0.000491
# INFO:absl:Step 9000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 89.90%, recall = 89.90%, precision = 100.00%, ambient false positives = 4, estimated false positives per hour = 0.41363, loss = 0.00590, auc = 0.97048, average viable recall = 0.888068364
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 89.00224%; no faph cutoff is 1.00
# INFO:absl:Step #9500: rate 0.001000, accuracy 99.99%, recall 99.96%, precision 99.87%, cross entropy 0.000322
# INFO:absl:Step 9500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 92.70%, recall = 92.70%, precision = 100.00%, ambient false positives = 12, estimated false positives per hour = 1.24089, loss = 0.00401, auc = 0.98246, average viable recall = 0.872379153
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 89.00224%; no faph cutoff is 1.00
# INFO:absl:Step #10000: rate 0.001000, accuracy 99.97%, recall 99.83%, precision 99.77%, cross entropy 0.000681
# INFO:absl:Step 10000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 96.50%, recall = 96.50%, precision = 100.00%, ambient false positives = 142, estimated false positives per hour = 14.68387, loss = 0.00574, auc = 0.99378, average viable recall = 0.314123689
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 89.00224%; no faph cutoff is 1.00
# INFO:absl:Sharding callback duration: 53
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 4
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 10
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 14
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 22
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 16
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (1, 204, 40)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expand_dims_1       │ (1, 204, 1, 40)   │          0 │ input_layer_1[0]… │
# │ (ExpandDims)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_6 (Stream)   │ (1, 67, 1, 32)    │      6,400 │ expand_dims_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (1, 67, 1, 32)    │          0 │ stream_6[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_7 (Stream)   │ (1, 67, 1, 32)    │          0 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_6  │ (1, 63, 1, 32)    │        192 │ stream_7[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (1, 63, 1, 64)    │      2,048 │ depthwise_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 63, 1, 64)    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (1, 63, 1, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_8 (Stream)   │ (1, 63, 1, 64)    │          0 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ channel_split_2     │ [(1, 63, 1, 32),  │          0 │ stream_8[0][0]    │
# │ (ChannelSplit)      │ (1, 63, 1, 32)]   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_4      │ (1, 63, 1, 32)    │          0 │ channel_split_2[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_5      │ (1, 63, 1, 32)    │          0 │ channel_split_2[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_7  │ (1, 57, 1, 32)    │        256 │ strided_keep_4[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_8  │ (1, 53, 1, 32)    │        384 │ strided_keep_5[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_4      │ (1, 53, 1, 32)    │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_5      │ (1, 53, 1, 32)    │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (1, 53, 1, 64)    │          0 │ strided_drop_4[0… │
# │ (Concatenate)       │                   │            │ strided_drop_5[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (1, 53, 1, 64)    │      4,096 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 53, 1, 64)    │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (1, 53, 1, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_9 (Stream)   │ (1, 53, 1, 64)    │          0 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ channel_split_3     │ [(1, 53, 1, 32),  │          0 │ stream_9[0][0]    │
# │ (ChannelSplit)      │ (1, 53, 1, 32)]   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_6      │ (1, 53, 1, 32)    │          0 │ channel_split_3[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_7      │ (1, 53, 1, 32)    │          0 │ channel_split_3[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_9  │ (1, 45, 1, 32)    │        320 │ strided_keep_6[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_10 │ (1, 39, 1, 32)    │        512 │ strided_keep_7[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_6      │ (1, 39, 1, 32)    │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_7      │ (1, 39, 1, 32)    │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (1, 39, 1, 64)    │          0 │ strided_drop_6[0… │
# │ (Concatenate)       │                   │            │ strided_drop_7[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (1, 39, 1, 64)    │      4,096 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 39, 1, 64)    │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (1, 39, 1, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_10 (Stream)  │ (1, 39, 1, 64)    │          0 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_11 │ (1, 17, 1, 64)    │      1,536 │ stream_10[0][0]   │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (1, 17, 1, 64)    │      4,096 │ depthwise_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 17, 1, 64)    │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (1, 17, 1, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_11 (Stream)  │ (1, 17, 1, 64)    │          0 │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (1, 1088)         │          0 │ stream_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (1, 1)            │      1,089 │ flatten_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 26,049 (101.75 KB)
#  Trainable params: 25,537 (99.75 KB)
#  Non-trainable params: 512 (2.00 KB)
# INFO:absl:None
# INFO:absl:Saving nonstreaming model
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (1, 204, 40)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expand_dims_1       │ (1, 204, 1, 40)   │          0 │ input_layer_1[0]… │
# │ (ExpandDims)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_6 (Stream)   │ (1, 67, 1, 32)    │      6,400 │ expand_dims_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (1, 67, 1, 32)    │          0 │ stream_6[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_7 (Stream)   │ (1, 67, 1, 32)    │          0 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_6  │ (1, 63, 1, 32)    │        192 │ stream_7[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (1, 63, 1, 64)    │      2,048 │ depthwise_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 63, 1, 64)    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (1, 63, 1, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_8 (Stream)   │ (1, 63, 1, 64)    │          0 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ channel_split_2     │ [(1, 63, 1, 32),  │          0 │ stream_8[0][0]    │
# │ (ChannelSplit)      │ (1, 63, 1, 32)]   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_4      │ (1, 63, 1, 32)    │          0 │ channel_split_2[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_5      │ (1, 63, 1, 32)    │          0 │ channel_split_2[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_7  │ (1, 57, 1, 32)    │        256 │ strided_keep_4[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_8  │ (1, 53, 1, 32)    │        384 │ strided_keep_5[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_4      │ (1, 53, 1, 32)    │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_5      │ (1, 53, 1, 32)    │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (1, 53, 1, 64)    │          0 │ strided_drop_4[0… │
# │ (Concatenate)       │                   │            │ strided_drop_5[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (1, 53, 1, 64)    │      4,096 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 53, 1, 64)    │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (1, 53, 1, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_9 (Stream)   │ (1, 53, 1, 64)    │          0 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ channel_split_3     │ [(1, 53, 1, 32),  │          0 │ stream_9[0][0]    │
# │ (ChannelSplit)      │ (1, 53, 1, 32)]   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_6      │ (1, 53, 1, 32)    │          0 │ channel_split_3[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_7      │ (1, 53, 1, 32)    │          0 │ channel_split_3[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_9  │ (1, 45, 1, 32)    │        320 │ strided_keep_6[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_10 │ (1, 39, 1, 32)    │        512 │ strided_keep_7[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_6      │ (1, 39, 1, 32)    │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_7      │ (1, 39, 1, 32)    │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (1, 39, 1, 64)    │          0 │ strided_drop_6[0… │
# │ (Concatenate)       │                   │            │ strided_drop_7[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (1, 39, 1, 64)    │      4,096 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 39, 1, 64)    │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (1, 39, 1, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_10 (Stream)  │ (1, 39, 1, 64)    │          0 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_11 │ (1, 17, 1, 64)    │      1,536 │ stream_10[0][0]   │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (1, 17, 1, 64)    │      4,096 │ depthwise_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 17, 1, 64)    │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (1, 17, 1, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_11 (Stream)  │ (1, 17, 1, 64)    │          0 │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (1, 1088)         │          0 │ stream_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (1, 1)            │      1,089 │ flatten_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 26,049 (101.75 KB)
#  Trainable params: 25,537 (99.75 KB)
#  Non-trainable params: 512 (2.00 KB)
# INFO:absl:Function `call` contains input name(s) resource with unsupported characters which will be renamed to dense_1_1_add_readvariableop_resource in the SavedModel.
# INFO:absl:Function `call` contains input name(s) resource with unsupported characters which will be renamed to dense_1_1_add_readvariableop_resource in the SavedModel.
# INFO:absl:Sharding callback duration: 60
# INFO:absl:Sharding callback duration: 128
# INFO:absl:Writing fingerprint to trained_models/wakeword/non_stream/fingerprint.pb
# Saved artifact at 'trained_models/wakeword/non_stream'. The following endpoints are available:
#
# * Endpoint 'serve'
#   inputs (POSITIONAL_OR_KEYWORD): TensorSpec(shape=(1, 204, 40), dtype=tf.float32, name=None)
#   training (POSITIONAL_OR_KEYWORD): Literal[None]
#   mask (POSITIONAL_OR_KEYWORD): Literal[None]
# Output Type:
#   TensorSpec(shape=(1, 1), dtype=tf.float32, name=None)
# Captures:
#   130478956597792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130450145500976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130450145494992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130450145500272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130450145505552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130450145498864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130450145495696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130450145504320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449770768064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449770762080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130450145502208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449770762256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449770774048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449770765248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130450145497104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130450145501856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130478956540176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449770774224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449303878496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449770772464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449303867408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449303878672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449303849968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449303851728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449303850672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449303854368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449303861936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449303862112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449303854896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449303781968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449303783728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449303782672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449303786368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449303795344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   130449303795520: TensorSpec(shape=(), dtype=tf.resource, name=None)
# INFO:absl:Converting nonstreaming model to TFLite
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1752731362.694059  212275 tf_tfl_flatbuffer_helpers.cc:390] Ignored output_format.
# W0000 00:00:1752731362.694279  212275 tf_tfl_flatbuffer_helpers.cc:393] Ignored drop_control_dependency.
# 2025-07-17 14:49:22.694615: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: trained_models/wakeword/non_stream
# 2025-07-17 14:49:22.695751: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2025-07-17 14:49:22.695765: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: trained_models/wakeword/non_stream
# 2025-07-17 14:49:22.718749: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# 2025-07-17 14:49:22.720922: I tensorflow/cc/saved_model/loader.cc:234] Restoring SavedModel bundle.
# 2025-07-17 14:49:22.797622: I tensorflow/cc/saved_model/loader.cc:218] Running initialization op on SavedModel bundle at path: trained_models/wakeword/non_stream
# 2025-07-17 14:49:22.817892: I tensorflow/cc/saved_model/loader.cc:317] SavedModel load for tags { serve }; Status: success: OK. Took 123289 microseconds.
# 2025-07-17 14:49:22.855472: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-07-17 14:49:22.933035: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:3064] Estimated count of arithmetic ops: 2.230 M  ops, equivalently 1.115 M  MACs
# INFO:absl:Testing the TFLite nonstreaming model false accept per hour and false rejection rates at various cutoffs.
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# INFO:absl:Testing the testing_ambient set.
# INFO:absl:Testing the testing set.
# INFO:absl:AUC 0.46095
# INFO:absl:Cutoff 1.00: frr=1.0000; faph=0.000
# INFO:absl:Cutoff 0.98: frr=0.0700; faph=0.751
# INFO:absl:Cutoff 0.95: frr=0.0500; faph=0.938
# INFO:absl:Cutoff 0.94: frr=0.0500; faph=1.126
# INFO:absl:Cutoff 0.92: frr=0.0400; faph=1.877
# INFO:absl:Cutoff 0.92: frr=0.0400; faph=2.000

# %%
# # Downloads the tflite model file. To use on the device, you need to write a
# # Model JSON file. See https://esphome.io/components/micro_wake_word for the
# # documentation and
# # https://github.com/esphome/micro-wake-word-models/tree/main/models/v2 for
# # examples. Adjust the probability threshold based on the test results obtained
# # after training is finished. You may also need to increase the Tensor arena
# # model size if the model fails to load.

# from google.colab import files

# files.download(f"trained_models/wakeword/tflite_stream_state_internal_quant/stream_state_internal_quant.tflite")


import os, shutil, sys, importlib.util
from pathlib import Path

tflite_path = Path(
    "trained_models/wakeword/tflite_stream_state_internal_quant/stream_state_internal_quant.tflite"
)

# 1) Colab 인지 확인
if importlib.util.find_spec("google.colab") is not None and "google.colab" in sys.modules:
    from google.colab import files
    files.download(str(tflite_path))
    print("⬇️  Colab: 파일 다운로드 창이 열렸습니다.")
else:
    # 2-a) 노트북 환경이면 클릭 가능한 링크 표시
    try:
        from IPython.display import FileLink, display  # Jupyter/VSCode
        display(FileLink(str(tflite_path)))
        print("🔗  위 링크를 클릭해 파일을 저장하세요.")
    except ImportError:
        # 2-b) 순수 CLI라면, 현재 작업 디렉터리로 복사
        dest = Path.cwd() / tflite_path.name
        shutil.copy(tflite_path, dest)
        print(f"📁  {dest} 로 파일을 복사했습니다.")
# Out:
# /home/kist/Workspace/Python/microWakeWord/notebooks/trained_models/wakeword/tflite_stream_state_internal_quant/stream_state_internal_quant.tflite
# 🔗  위 링크를 클릭해 파일을 저장하세요.
